# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import seaborn as sns

# %%
# iterate through API requests. Records are stored in 'collected_data'
# this cell takes approximately 5 minutes to run

collected_data = []

for i in range(1,500,1):
    request_string = "https://api.themoviedb.org/3/discover/movie?api_key=afc7201593c1f2fc08c24eec64fabc88&language=en-US&sort_by=popularity.desc&include_adult=false&include_video=false&primary_release_date.lte=2019-12-30&primary_release_date.gte=2000-01-01&page="+str(i)
    data = requests.get(request_string)
    data = data.json()['results']
    for item in data:
        collected_data.append(item)

# %%
#load data into dataframe
df = pd.DataFrame(collected_data)

# %%
df
# Out:
#       adult                     backdrop_path                    genre_ids  \
# 0     False  /wFN8llYh215M8i2fqWAcPV8CSyL.jpg  [28, 12, 16, 35, 10751, 14]
# 1     False  /9guoVF7zayiiUq5ulKQpt375VIy.jpg         [16, 28, 35, 14, 12]
# 2     False  /6iUNJZymJBMXXriQyFZfLAKnjO6.jpg                 [28, 12, 14]
# 3     False                              None                           []
# 4     False  /4dtbvoAaqiM3fVwzdffLxUdAiY6.jpg              [10751, 35, 14]
# ...     ...                               ...                          ...
# 9975  False  /3VTif2JwpBPKdrQnIdTbbs1Fxau.jpg      [14, 878, 10751, 10770]
# 9976  False  /p8oxdizsjwFmEmI70gkBPe3XpwU.jpg           [10749, 10770, 35]
# 9977  False                              None                         [16]
# 9978  False  /gHUDHuwEOnHrMihVB0oW8TCnBGF.jpg                     [35, 99]
# 9979  False  /4NMit7ynHRepDYfgNSX4VU3pQU1.jpg                     [35, 18]
#
#           id original_language                       original_title  \
# 0      49519                en                           The Croods
# 1     592350                ja    僕のヒーローアカデミア THE MOVIE ヒーローズ：ライジング
# 2     297762                en                         Wonder Woman
# 3     749336                en  Star Wars: Wrath of the Mandalorian
# 4       8871                en       How the Grinch Stole Christmas
# ...      ...               ...                                  ...
# 9975   68591                en                            Snowglobe
# 9976  474979                en                 Royal New Year's Eve
# 9977  284866                en                       Sonic Prologue
# 9978  473812                en                Jerry Before Seinfeld
# 9979  358725                fr                          Saint Amour
#
#                                                overview  popularity  \
# 0     The prehistoric Croods family live in a partic...     373.299
# 1     Class 1-A visits Nabu Island where they finall...     332.804
# 2     An Amazon princess comes to the world of Man i...     318.625
# 3     Years after the Clone Wars end, Darth Vader se...     248.752
# 4     Inside a snowflake exists the magical land of ...     234.077
# ...                                                 ...         ...
# 9975  A young woman discovers a Christmas-themed dre...       7.295
# 9976  An aspiring fashion designer falls in love wit...       7.294
# 9977  Take a step back in time as Sonic the Hedgehog...       7.294
# 9978  Jerry Seinfeld returns to the club that gave h...       7.293
# 9979  Every year, Bruno makes a tour of all the wine...       7.293
#
#                            poster_path release_date  \
# 0     /27zvjVOtOi5ped1HSlJKNsKXkFH.jpg   2013-03-20
# 1     /zGVbrulkupqpbwgiNedkJPyQum4.jpg   2019-12-20
# 2     /gfJGlDaHuWimErCr5Ql0I8x9QSy.jpg   2017-05-30
# 3     /ksil1FjB7AfNk34LAti0636pyTd.jpg   2008-07-06
# 4     /1WZbbPApEivA421gCOluuzMMKCk.jpg   2000-11-17
# ...                                ...          ...
# 9975  /8MCX4KlF8O3cdoSiX1jiUsyVXMp.jpg   2007-12-15
# 9976  /rWwWwJb9F32xsLQ382Qd0e0hsML.jpg   2017-12-30
# 9977  /h4Pl9047A2sX97DLruAy5DbXgqj.jpg   2014-08-02
# 9978  /1HsldceVUztgRztwp3pOaVRJVlp.jpg   2017-09-19
# 9979  /A9wTBWnx6nKitul3vjKHrRKjWRk.jpg   2016-03-02
#
#                                     title  video  vote_average  vote_count
# 0                              The Croods  False           6.9        5021
# 1         My Hero Academia: Heroes Rising  False           8.5         525
# 2                            Wonder Woman  False           7.3       15558
# 3     Star Wars: Wrath of the Mandalorian  False           7.4          15
# 4          How the Grinch Stole Christmas  False           6.7        4915
# ...                                   ...    ...           ...         ...
# 9975                            Snowglobe  False           6.2          38
# 9976                 Royal New Year's Eve  False           6.2          53
# 9977                       Sonic Prologue  False           8.9           4
# 9978                Jerry Before Seinfeld  False           6.9          77
# 9979                          Saint Amour  False           5.9         111
#
# [9980 rows x 14 columns]

# %%
# The 'discover' API is missing budget, revenue, imdb_id, and runtime
# these can be pulled from the 'movie' API call. this cell prepares for the next for loop to pull this required data
budget = []
imdb_id = []
revenue = []
runtime = []
production_companies = []
production_countries = []
genres = []

# %%
#create a list of tmdb-movie-ids to iterate through. each id will be used in its own API call
#for each movie_id defined above, call API to to retrieve budget, revenue, imdb_id, runtime.
#tmdb data structure isn't uniform. movie dictionaries do not necessarily have all keys.
#to get around this, we used try/except
#this cell takes about 30 minutes to run
movie_ids = list(df['id'])
for movie_id in movie_ids:
    request_string = "https://api.themoviedb.org/3/movie/"+str(movie_id)+"?api_key=afc7201593c1f2fc08c24eec64fabc88&language=en-US"
    data = requests.get(request_string)
    data = data.json()
    try:
        budget.append(data['budget'])
    except:
        budget.append(" ")
    try:
        imdb_id.append(data['imdb_id'])
    except:
        imdb_id.append(" ")
    try:
        revenue.append(data['revenue'])
    except:
        revenue.append(" ")
    try:
        runtime.append(data['runtime'])
    except:
        runtime.append(" ")
    try:
        production_companies.append(data['production_companies'])
    except:
        production_companies.append(" ")
    try:
        production_countries.append(data['production_countries'])
    except:
        production_countries.append(" ")
    try:
        genres.append(data['genres'])
    except:
        genres.append(" ")

# %%
# Finally append the new columns to the final DataFrame
df['budget']=budget
df['imdb_id']=imdb_id
df['runtime']= runtime 
df['production_companies']=production_companies
df['production_countries']=production_companies
df['genres']=genres
df['revenue']=revenue

# %%
#save raw API results to csv
df.to_csv('tmdb_raw.csv',index=False)

# %%
#load raw data from csv
df=pd.read_csv('tmdb_raw.csv')

# %%
df
# Out:
#        adult                     backdrop_path                    genre_ids  \
# 0      False  /wFN8llYh215M8i2fqWAcPV8CSyL.jpg  [28, 12, 16, 35, 10751, 14]
# 1      False  /9guoVF7zayiiUq5ulKQpt375VIy.jpg         [16, 28, 35, 14, 12]
# 2      False  /6iUNJZymJBMXXriQyFZfLAKnjO6.jpg                 [28, 12, 14]
# 3      False                               NaN                           []
# 4      False  /4dtbvoAaqiM3fVwzdffLxUdAiY6.jpg              [10751, 35, 14]
# ...      ...                               ...                          ...
# 34223  False  /3VTif2JwpBPKdrQnIdTbbs1Fxau.jpg      [14, 878, 10751, 10770]
# 34224  False  /p8oxdizsjwFmEmI70gkBPe3XpwU.jpg           [10749, 10770, 35]
# 34225  False                               NaN                         [16]
# 34226  False  /gHUDHuwEOnHrMihVB0oW8TCnBGF.jpg                     [35, 99]
# 34227  False  /4NMit7ynHRepDYfgNSX4VU3pQU1.jpg                     [35, 18]
#
#            id original_language                       original_title  \
# 0       49519                en                           The Croods
# 1      592350                ja    僕のヒーローアカデミア THE MOVIE ヒーローズ：ライジング
# 2      297762                en                         Wonder Woman
# 3      749336                en  Star Wars: Wrath of the Mandalorian
# 4        8871                en       How the Grinch Stole Christmas
# ...       ...               ...                                  ...
# 34223   68591                en                            Snowglobe
# 34224  474979                en                 Royal New Year's Eve
# 34225  284866                en                       Sonic Prologue
# 34226  473812                en                Jerry Before Seinfeld
# 34227  358725                fr                          Saint Amour
#
#                                                 overview  popularity  \
# 0      The prehistoric Croods family live in a partic...     373.299
# 1      Class 1-A visits Nabu Island where they finall...     332.804
# 2      An Amazon princess comes to the world of Man i...     318.625
# 3      Years after the Clone Wars end, Darth Vader se...     248.752
# 4      Inside a snowflake exists the magical land of ...     234.077
# ...                                                  ...         ...
# 34223  A young woman discovers a Christmas-themed dre...       7.295
# 34224  An aspiring fashion designer falls in love wit...       7.294
# 34225  Take a step back in time as Sonic the Hedgehog...       7.294
# 34226  Jerry Seinfeld returns to the club that gave h...       7.293
# 34227  Every year, Bruno makes a tour of all the wine...       7.293
#
#                             poster_path release_date  ...  video vote_average  \
# 0      /27zvjVOtOi5ped1HSlJKNsKXkFH.jpg   2013-03-20  ...  False          6.9
# 1      /zGVbrulkupqpbwgiNedkJPyQum4.jpg   2019-12-20  ...  False          8.5
# 2      /gfJGlDaHuWimErCr5Ql0I8x9QSy.jpg   2017-05-30  ...  False          7.3
# 3      /ksil1FjB7AfNk34LAti0636pyTd.jpg   2008-07-06  ...  False          7.4
# 4      /1WZbbPApEivA421gCOluuzMMKCk.jpg   2000-11-17  ...  False          6.7
# ...                                 ...          ...  ...    ...          ...
# 34223  /8MCX4KlF8O3cdoSiX1jiUsyVXMp.jpg   2007-12-15  ...  False          6.2
# 34224  /rWwWwJb9F32xsLQ382Qd0e0hsML.jpg   2017-12-30  ...  False          6.2
# 34225  /h4Pl9047A2sX97DLruAy5DbXgqj.jpg   2014-08-02  ...  False          8.9
# 34226  /1HsldceVUztgRztwp3pOaVRJVlp.jpg   2017-09-19  ...  False          6.9
# 34227  /A9wTBWnx6nKitul3vjKHrRKjWRk.jpg   2016-03-02  ...  False          5.9
#
#       vote_count     budget     imdb_id runtime  \
# 0           5021  135000000   tt0481499      98
# 1            525          0  tt11107074     104
# 2          15558  149000000   tt0451279     141
# 3             15          0   tt2351379      12
# 4           4915  123000000   tt0170016     104
# ...          ...        ...         ...     ...
# 34223         38          0   tt1068284     120
# 34224         53          0   tt7654082      84
# 34225          4       5000   tt8246466      25
# 34226         77          0   tt7310906      62
# 34227        111          0   tt4589186     101
#
#                                     production_companies  \
# 0      [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...
# 1      [{'id': 2849, 'logo_path': '/cN3JNIKawjOMtfk0G...
# 2      [{'id': 174, 'logo_path': '/ky0xOc5OrhzkZ1N6Ky...
# 3                                                     []
# 4      [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# ...                                                  ...
# 34223  [{'id': 5948, 'logo_path': None, 'name': 'ABC ...
# 34224  [{'id': 53015, 'logo_path': None, 'name': 'Cro...
# 34225                                                 []
# 34226  [{'id': 23601, 'logo_path': '/jZYnbLWzOGhRDrvL...
# 34227  [{'id': 7561, 'logo_path': '/yWTuzkQnp4NCS7fDV...
#
#                                     production_countries  \
# 0      [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...
# 1      [{'id': 2849, 'logo_path': '/cN3JNIKawjOMtfk0G...
# 2      [{'id': 174, 'logo_path': '/ky0xOc5OrhzkZ1N6Ky...
# 3                                                     []
# 4      [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# ...                                                  ...
# 34223  [{'id': 5948, 'logo_path': None, 'name': 'ABC ...
# 34224  [{'id': 53015, 'logo_path': None, 'name': 'Cro...
# 34225                                                 []
# 34226  [{'id': 23601, 'logo_path': '/jZYnbLWzOGhRDrvL...
# 34227  [{'id': 7561, 'logo_path': '/yWTuzkQnp4NCS7fDV...
#
#                                                   genres    revenue
# 0      [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  587204668
# 1      [{'id': 16, 'name': 'Animation'}, {'id': 28, '...   29900850
# 2      [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  821847012
# 3                                                     []          0
# 4      [{'id': 10751, 'name': 'Family'}, {'id': 35, '...  345141403
# ...                                                  ...        ...
# 34223  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...          0
# 34224  [{'id': 10749, 'name': 'Romance'}, {'id': 1077...          0
# 34225                  [{'id': 16, 'name': 'Animation'}]          0
# 34226  [{'id': 35, 'name': 'Comedy'}, {'id': 99, 'nam...          0
# 34227  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...          0
#
# [34228 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34228 entries, 0 to 34227
# Data columns (total 21 columns):
# adult                   34228 non-null object
# backdrop_path           9305 non-null object
# genre_ids               34228 non-null object
# id                      34228 non-null object
# original_language       34228 non-null object
# original_title          34228 non-null object
# overview                34187 non-null object
# popularity              9980 non-null float64
# poster_path             9859 non-null object
# release_date            9980 non-null object
# title                   9980 non-null object
# video                   9980 non-null object
# vote_average            9980 non-null object
# vote_count              9980 non-null object
# budget                  9980 non-null object
# imdb_id                 9805 non-null object
# runtime                 9952 non-null object
# production_companies    9979 non-null object
# production_countries    9979 non-null object
# genres                  9979 non-null object
# revenue                 9979 non-null object
# dtypes: float64(1), object(20)
# memory usage: 5.5+ MB

# %%
# Separating our release date into year and month.
df['release_year'] = df['release_date'].apply(lambda x: int(x[0:4]))
df['release_month'] = df['release_date'].apply(lambda x: int(x[5:7]))
df.drop('release_date',axis= 1,inplace=True)

# %%
# Removing unnecessary information
df.drop(['poster_path','video','backdrop_path','adult','original_language','genre_ids','original_title'],axis=1,inplace=True)

#Rearranging columns with a more easy to read order.
new_col=[ 'id', 'title', 'imdb_id','genres','overview', 'budget', 'release_year','release_month','popularity', 'vote_count','vote_average','revenue', 'runtime','production_companies', 'production_countries']
df=df[new_col]
# Dropping irrelevant missing data 
to_drop=df[(df.production_companies==" ")|(df.imdb_id=='')].index#(df.revenue==0)|(df.budget==0)|(df.runtime.isna())].index
df.drop(to_drop,inplace=True)


# Unpacking dictionaries from strings
df.production_companies = [eval(key) for key in df.production_companies]
df.production_countries= [eval(key) for key in df.production_countries]
df.genres= [eval(key) for key in df.genres]

# Resetting the index to maintain cohesive rows.
df.reset_index(drop=True,inplace=True)
